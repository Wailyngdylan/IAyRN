# %% [markdown]
# # A2: Ejercicios en Python 1
# Nombre: Brandon Dylan Regil Llovera
#
# Matricula: 1872756
#
# Horas clase: LMV N1

# %% [markdown]
# Escribe un programa que le pida al usuario por su nombre y que lo salude con su nombre, excepto si se llama “Ana”, “Juan”, y “Pedro”.

# %%
x='Ana'
y='Juan'
z='Pedro'
mensaje=input('Dime tu nombre:')
if mensaje==x:
 print('no te conozco')
elif mensaje==y:
  print('no te conozco')
elif mensaje==z:
  print('no te conozco')
else:
  print('Hola, mucho gusto',mensaje)
# Out:
# Dime tu nombre:Ana
# no te conozco

# %% [markdown]
# Escribe una función que regrese el último elemento de una lista y que revierta el orden de la lista e imprima la lista revertida.

# %%
 def funcion(colores):
  print(colores[::-1])
 lista=['amarillo','blanco','cafe','dorado','esmeralda']
 print(lista)
 print()
 funcion(lista)
# Out:
# ['amarillo', 'blanco', 'cafe', 'dorado', 'esmeralda']
#
# ['esmeralda', 'dorado', 'cafe', 'blanco', 'amarillo']

# %% [markdown]
# Escribe una función que toma una lista de strings y los imprima línea por línea en un marco rectangular. Por ejemplo, la lista [“Hola”, “a”, “todos”, “esto”, “es”, “un”, “marco”] se imprime:

# %%
def funcion(oracion):
 for x in oracion:
  print(x)
lista=['Hola','tenemos','muchas','ganas','de','aprender','Phyton']
funcion(lista)
# Out:
# Hola
# tenemos
# muchas
# ganas
# de
# aprender
# Phyton
